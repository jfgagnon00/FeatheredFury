# %%
#
# assure le reload de src si modifications sont faite
#
# %load_ext autoreload
# %autoreload 2

# %%
#
# import utilitaires
#
from pathlib import Path
from src.configs import create_config
from src.data import create_datahandler
from src.logging import create_logger
from src.metrics import create_metrics_provider
from src.models import create_model
from src.features import create_features_selector

def get_dataset_config():
    path = Path.joinpath(Path.cwd(), Path("../configs/winequality-red.yaml"))
    return create_config( str(path) )

def get_train_config():
    path = Path.joinpath(Path.cwd(), Path("../configs/train_validate.yaml"))
    return create_config( str(path) )

def get_model_config():
    path = Path.joinpath(Path.cwd(), Path("../configs/ElasticNet.yaml"))
    return create_config( str(path) )
